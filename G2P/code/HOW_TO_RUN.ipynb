# %%
# !pip install jiwer

# %% [markdown]
# ## Encoder-Decoder

# %% [markdown]
# ### encoder-decoder using **unigram**

# %% [markdown]
# #### Train

# %%
# !python train.py --model 'encoder_decoder' --save_model_path 'models/' --n_gram 'unigram' --data_path 'data/train_data.txt' --batch_size 32  --val_size 0.01
# Out:
# reading data ...
# creating matrixes ...
# 2022-11-07 18:25:49.392256: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# train data is prepaired.
# building model..
# start training..
# ...
# 2011/2011 [==============================] - 40s 20ms/step - loss: 0.0187 - val_loss: 0.0384
# model is trained.
# Figure(640x480)

# %% [markdown]
# #### Test

# %%
# !python test.py --model 'encoder_decoder' --data_path 'data/test_data.txt' --n_gram 'unigram' --verbose True
# Out:
# 2022-11-07 19:58:17.693025: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# reading data ...
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# ...

# %% [markdown]
# ### encoder-decoder using **bigram**

# %% [markdown]
# #### Train

# %%
# !python train.py --model 'encoder_decoder' --save_model_path 'models/' --n_gram 'bigram' --data_path 'data/train_data.txt' --batch_size 32  --val_size 0.01
# Out:
# reading data ...
# creating matrixes ...
# 2022-11-07 19:12:03.424912: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# train data is prepaired.
# building model..
# start training..
# ...
# 2011/2011 [==============================] - 43s 21ms/step - loss: 0.0213 - val_loss: 0.0370
# model is trained.
# Figure(640x480)

# %% [markdown]
# #### Test

# %%
# !python test.py --model 'encoder_decoder' --data_path 'data/test_data.txt' --n_gram 'bigram' --verbose True
# Out:
# 2022-11-07 19:43:35.708265: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# reading data ...
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# ...

# %% [markdown]
# ## Transformer

# %% [markdown]
# ### transformer using **unigram**

# %% [markdown]
# #### Train

# %%
# !python train.py --model 'transformer' --save_model_path 'models/' --n_gram 'unigram' --data_path 'data/train_data.txt' --batch_size 32  --val_size 0.01
# Out:
# reading data ...
# creating matrixes ...
# 2022-11-07 21:26:51.701916: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# train data is prepaired.
# building model..
# start training..
# ...
# 2011/2011 [==============================] - 66s 33ms/step - loss: 0.0389 - val_loss: 0.0391
# model is trained.
# Figure(640x480)

# %% [markdown]
# #### Test

# %%
# !python test.py --model 'transformer' --data_path 'data/test_data.txt' --n_gram 'unigram' --verbose True
# Out:
# 2022-11-07 20:35:26.392231: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# reading data ...
# grapheme input: خاک‌پاش
# model outpu: xAkpAS
#
# grapheme input: فضایح
# model outpu: fazAyeh
#
# grapheme input: خراب‌شده
# model outpu: xorAbSode
#
# grapheme input: تریتیم
# model outpu: teritim
#
# grapheme input: محاولت
# model outpu: mohAvelat
#
# grapheme input: داغمه
# model outpu: dAqame
#
# grapheme input: شیبانی
# model outpu: SeybAni
#
# grapheme input: آنتی‌توکسین
# model outpu: 'Antituksin
#
# grapheme input: غرب‌شناسی
# model outpu: qorbSenAsi
#
# grapheme input: محسنی‌نسب
# model outpu: mohseninasab
#
# grapheme input: سرچسب
# model outpu: sarCasb
#
# grapheme input: نوم
# model outpu: nom
#
# grapheme input: بوالحسن
# model outpu: bolhosn
#
# grapheme input: ران
# model outpu: rAn
#
# grapheme input: طیت
# model outpu: teyyat
#
# ...

# %% [markdown]
# ### transformer using **bigram**

# %% [markdown]
# #### Train

# %%
# !python train.py --model 'transformer' --save_model_path 'models/' --n_gram 'bigram' --data_path 'data/train_data.txt' --batch_size 32  --val_size 0.01
# Out:
# reading data ...
# creating matrixes ...
# 2022-11-07 21:38:39.929847: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# train data is prepaired.
# building model..
# start training..
# ...
# 2011/2011 [==============================] - 68s 34ms/step - loss: 0.0336 - val_loss: 0.0380
# model is trained.
# Figure(640x480)

# %% [markdown]
# #### Test

# %%
# !python test.py --model 'transformer' --data_path 'data/test_data.txt' --n_gram 'bigram' --verbose True
# Out:
# 2022-11-07 21:10:36.666405: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# reading data ...
# grapheme input: خاک‌پاش
# model outpu: xAkpAS
#
# grapheme input: فضایح
# model outpu: fazAyeh
#
# grapheme input: خراب‌شده
# model outpu: xarAbSode
#
# grapheme input: تریتیم
# model outpu: teritim
#
# grapheme input: محاولت
# model outpu: mohAvelat
#
# grapheme input: داغمه
# model outpu: dAqeme
#
# grapheme input: شیبانی
# model outpu: SibAni
#
# grapheme input: آنتی‌توکسین
# model outpu: 'Antitoksin
#
# grapheme input: غرب‌شناسی
# model outpu: qarbSenAsi
#
# grapheme input: محسنی‌نسب
# model outpu: mohsannesab
#
# grapheme input: سرچسب
# model outpu: sarCasb
#
# grapheme input: نوم
# model outpu: nom
#
# grapheme input: بوالحسن
# model outpu: bolhasan
#
# grapheme input: ران
# model outpu: rAn
#
# grapheme input: طیت
# model outpu: teyt
#
# ...

# %% [markdown]
# #### install packages

# %%
# %pip install -U transformers datasets   
# %pip install tensorboard==1.14.0
# %pip install -U evaluate

# %% [markdown]
# #### download pquad and squad2 data

# %%
# !mkdir data

# !mkdir data/squad
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json" -O data/squad/train.json
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json" -O data/squad/test.json

# !mkdir data/pquad
# !wget "https://github.com/AUT-NLP/PQuAD/raw/main/Dataset/Train.json" -O data/pquad/train.json
# !wget "https://github.com/AUT-NLP/PQuAD/raw/main/Dataset/Test.json" -O data/pquad/test.json
# !wget "https://github.com/AUT-NLP/PQuAD/raw/main/Dataset/Validation.json" -O data/pquad/val.json
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2023-01-23 15:38:33--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.111.153, 185.199.110.153, 185.199.109.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘data/squad/train.json’
#
# data/squad/train.js 100%[===================>]  40.17M   155KB/s    in 8m 2s
#
# 2023-01-23 15:46:37 (85.3 KB/s) - ‘data/squad/train.json’ saved [42123633/42123633]
#
# --2023-01-23 15:46:37--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.110.153, 185.199.108.153, 185.199.109.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %% [markdown]
# ## Pars Bert

# %% [markdown]
# ### Train model

# %%
# !python3 train.py --model_type pretrained_parsbert

# %% [markdown]
# ### Test

# %%
# !python3 test.py --model_type pretrained_parsbert

# %% [markdown]
# ### Show examples

# %%
# !python3 test.py --model_type pretrained_parsbert  --example_number 0

# %% [markdown]
# ## Not pretrained Bert

# %% [markdown]
# ### Train

# %%
# !python3 train.py --model_type untrained_bert

# %% [markdown]
# ### Test

# %%
# !python3 test.py --model_type untrained_bert

# %% [markdown]
# ### Show example

# %%
# !python3 test.py --model_type untrained_bert  --example_number 1

# %% [markdown]
# ## Multi-lingual XLM-Roberta

# %% [markdown]
# ### Train

# %%
# !python3 train.py --model_type pretrained_xlm_roberta

# %% [markdown]
# ### Test

# %%
# !python3 test.py --model_type pretrained_xlm_roberta

# %% [markdown]
# ### Show example

# %%
# !python3 test.py --model_type pretrained_xlm_roberta  --example_number 1
